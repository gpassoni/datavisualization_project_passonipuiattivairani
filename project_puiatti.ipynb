# %%
import pandas as pd
from sklearn.impute import KNNImputer
import plotly.express as px
from geopy.exc import GeocoderTimedOut
from geopy.geocoders import Nominatim
import numpy as np

# %%
df = pd.read_csv("statics/HDR21-22_Composite_indices_complete_time_series.csv")
df
# Out:
#           iso3                          country    hdicode region  \
# 0          AFG                      Afghanistan        Low     SA
# 1          AGO                           Angola     Medium    SSA
# 2          ALB                          Albania       High    ECA
# 3          AND                          Andorra  Very High    NaN
# 4          ARE             United Arab Emirates  Very High     AS
# ..         ...                              ...        ...    ...
# 201    ZZG.ECA          Europe and Central Asia        NaN    NaN
# 202    ZZH.LAC  Latin America and the Caribbean        NaN    NaN
# 203     ZZI.SA                       South Asia        NaN    NaN
# 204    ZZJ.SSA               Sub-Saharan Africa        NaN    NaN
# 205  ZZK.WORLD                            World        NaN    NaN
#
#      hdi_rank_2021  hdi_1990  hdi_1991  hdi_1992  hdi_1993  hdi_1994  ...  \
# 0            180.0     0.273     0.279     0.287     0.297     0.292  ...
# 1            148.0       NaN       NaN       NaN       NaN       NaN  ...
# 2             67.0     0.647     0.629     0.614     0.617     0.624  ...
# 3             40.0       NaN       NaN       NaN       NaN       NaN  ...
# 4             26.0     0.728     0.739     0.742     0.748     0.755  ...
# ..             ...       ...       ...       ...       ...       ...  ...
# 201            NaN     0.664     0.661     0.654     0.652     0.647  ...
# 202            NaN     0.633     0.638     0.643     0.648     0.654  ...
# 203            NaN     0.442     0.447     0.453     0.457     0.462  ...
# 204            NaN     0.407     0.410     0.410     0.411     0.413  ...
# 205            NaN     0.601     0.604     0.607     0.610     0.614  ...
#
#        mf_2012    mf_2013    mf_2014    mf_2015    mf_2016    mf_2017  \
# 0     1.860000   1.880000   1.660000   1.620000   1.660000   1.410000
# 1     4.090000   4.530000   3.970000   3.590000   2.790000   2.640000
# 2    12.440000  11.490000  13.140000  12.610000  14.390000  14.460000
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4    49.560000  49.680000  55.490000  59.760000  64.950000  75.610000
# ..         ...        ...        ...        ...        ...        ...
# 201  13.107171  14.172082  14.189127  14.523162  13.791770  13.618078
# 202  14.114108  14.493145  14.080904  14.146026  13.325144  13.604555
# 203   4.699407   4.584935   4.486500   4.610546   4.624886   4.740263
# 204   3.437760   3.530479   3.491150   3.494860   3.415511   3.256156
# 205  12.186601  12.474065  12.520563  12.372667  12.277707  12.277878
#
#        mf_2018    mf_2019    mf_2020    mf_2021
# 0     1.320000   1.380000   1.380000   1.380000
# 1     2.280000   2.180000   2.180000   2.180000
# 2    12.850000  12.960000  12.960000  12.960000
# 3          NaN        NaN        NaN        NaN
# 4    65.970000  68.950000  68.950000  68.950000
# ..         ...        ...        ...        ...
# 201  13.914030  14.087293  14.091826  14.096719
# 202  13.151315  13.296195  13.290914  13.284745
# 203   5.000024   5.110230   5.106447   5.102134
# 204   3.145930   3.151076   3.146092   3.140740
# 205  12.220286  12.375236  12.325166  12.271920
#
# [206 rows x 1008 columns]

# %%
df_numerics = df.select_dtypes(exclude = 'object')

# %%
knn_imp = KNNImputer(n_neighbors=20)
df_imputed = pd.DataFrame(knn_imp.fit_transform(df_numerics), columns=df_numerics.columns)
df_imputed
# Out:
#      hdi_rank_2021  hdi_1990  hdi_1991  hdi_1992  hdi_1993  hdi_1994  \
# 0           180.00   0.27300   0.27900   0.28700   0.29700    0.2920
# 1           148.00   0.51685   0.52020   0.52175   0.52455    0.5299
# 2            67.00   0.64700   0.62900   0.61400   0.61700    0.6240
# 3            40.00   0.80920   0.81415   0.82010   0.82630    0.8348
# 4            26.00   0.72800   0.73900   0.74200   0.74800    0.7550
# ..             ...       ...       ...       ...       ...       ...
# 201          80.95   0.66400   0.66100   0.65400   0.65200    0.6470
# 202          84.90   0.63300   0.63800   0.64300   0.64800    0.6540
# 203         135.75   0.44200   0.44700   0.45300   0.45700    0.4620
# 204         149.95   0.40700   0.41000   0.41000   0.41100    0.4130
# 205          82.15   0.60100   0.60400   0.60700   0.61000    0.6140
#
#      hdi_1995  hdi_1996  hdi_1997  hdi_1998  ...    mf_2012    mf_2013  \
# 0     0.31000   0.31900    0.3230   0.32400  ...   1.860000   1.880000
# 1     0.54200   0.54795    0.5513   0.55565  ...   4.090000   4.530000
# 2     0.63400   0.64500    0.6420   0.65700  ...  12.440000  11.490000
# 3     0.83875   0.84425    0.8499   0.85690  ...  29.288500  29.222000
# 4     0.76200   0.76700    0.7730   0.77900  ...  49.560000  49.680000
# ..        ...       ...       ...       ...  ...        ...        ...
# 201   0.65200   0.65600    0.6620   0.66900  ...  13.107171  14.172082
# 202   0.65800   0.66500    0.6720   0.67700  ...  14.114108  14.493145
# 203   0.46700   0.47400    0.4800   0.48600  ...   4.699407   4.584935
# 204   0.42000   0.42300    0.4270   0.42800  ...   3.437760   3.530479
# 205   0.61900   0.62400    0.6290   0.63400  ...  12.186601  12.474065
#
#        mf_2014    mf_2015    mf_2016    mf_2017    mf_2018    mf_2019  \
# 0     1.660000   1.620000   1.660000   1.410000   1.320000   1.380000
# 1     3.970000   3.590000   2.790000   2.640000   2.280000   2.180000
# 2    13.140000  12.610000  14.390000  14.460000  12.850000  12.960000
# 3    29.524000  29.033000  29.550500  30.422000  28.991500  28.891500
# 4    55.490000  59.760000  64.950000  75.610000  65.970000  68.950000
# ..         ...        ...        ...        ...        ...        ...
# 201  14.189127  14.523162  13.791770  13.618078  13.914030  14.087293
# 202  14.080904  14.146026  13.325144  13.604555  13.151315  13.296195
# 203   4.486500   4.610546   4.624886   4.740263   5.000024   5.110230
# 204   3.491150   3.494860   3.415511   3.256156   3.145930   3.151076
# 205  12.520563  12.372667  12.277707  12.277878  12.220286  12.375236
#
#        mf_2020    mf_2021
# 0     1.380000   1.380000
# 1     2.180000   2.180000
# 2    12.960000  12.960000
# 3    28.891500  28.891500
# 4    68.950000  68.950000
# ..         ...        ...
# 201  14.091826  14.096719
# 202  13.290914  13.284745
# 203   5.106447   5.102134
# 204   3.146092   3.140740
# 205  12.325166  12.271920
#
# [206 rows x 1004 columns]

# %%
df[df_numerics.columns] = df_imputed
df
# Out:
#           iso3                          country    hdicode region  \
# 0          AFG                      Afghanistan        Low     SA
# 1          AGO                           Angola     Medium    SSA
# 2          ALB                          Albania       High    ECA
# 3          AND                          Andorra  Very High    NaN
# 4          ARE             United Arab Emirates  Very High     AS
# ..         ...                              ...        ...    ...
# 201    ZZG.ECA          Europe and Central Asia        NaN    NaN
# 202    ZZH.LAC  Latin America and the Caribbean        NaN    NaN
# 203     ZZI.SA                       South Asia        NaN    NaN
# 204    ZZJ.SSA               Sub-Saharan Africa        NaN    NaN
# 205  ZZK.WORLD                            World        NaN    NaN
#
#      hdi_rank_2021  hdi_1990  hdi_1991  hdi_1992  hdi_1993  hdi_1994  ...  \
# 0           180.00   0.27300   0.27900   0.28700   0.29700    0.2920  ...
# 1           148.00   0.51685   0.52020   0.52175   0.52455    0.5299  ...
# 2            67.00   0.64700   0.62900   0.61400   0.61700    0.6240  ...
# 3            40.00   0.80920   0.81415   0.82010   0.82630    0.8348  ...
# 4            26.00   0.72800   0.73900   0.74200   0.74800    0.7550  ...
# ..             ...       ...       ...       ...       ...       ...  ...
# 201          80.95   0.66400   0.66100   0.65400   0.65200    0.6470  ...
# 202          84.90   0.63300   0.63800   0.64300   0.64800    0.6540  ...
# 203         135.75   0.44200   0.44700   0.45300   0.45700    0.4620  ...
# 204         149.95   0.40700   0.41000   0.41000   0.41100    0.4130  ...
# 205          82.15   0.60100   0.60400   0.60700   0.61000    0.6140  ...
#
#        mf_2012    mf_2013    mf_2014    mf_2015    mf_2016    mf_2017  \
# 0     1.860000   1.880000   1.660000   1.620000   1.660000   1.410000
# 1     4.090000   4.530000   3.970000   3.590000   2.790000   2.640000
# 2    12.440000  11.490000  13.140000  12.610000  14.390000  14.460000
# 3    29.288500  29.222000  29.524000  29.033000  29.550500  30.422000
# 4    49.560000  49.680000  55.490000  59.760000  64.950000  75.610000
# ..         ...        ...        ...        ...        ...        ...
# 201  13.107171  14.172082  14.189127  14.523162  13.791770  13.618078
# 202  14.114108  14.493145  14.080904  14.146026  13.325144  13.604555
# 203   4.699407   4.584935   4.486500   4.610546   4.624886   4.740263
# 204   3.437760   3.530479   3.491150   3.494860   3.415511   3.256156
# 205  12.186601  12.474065  12.520563  12.372667  12.277707  12.277878
#
#        mf_2018    mf_2019    mf_2020    mf_2021
# 0     1.320000   1.380000   1.380000   1.380000
# 1     2.280000   2.180000   2.180000   2.180000
# 2    12.850000  12.960000  12.960000  12.960000
# 3    28.991500  28.891500  28.891500  28.891500
# 4    65.970000  68.950000  68.950000  68.950000
# ..         ...        ...        ...        ...
# 201  13.914030  14.087293  14.091826  14.096719
# 202  13.151315  13.296195  13.290914  13.284745
# 203   5.000024   5.110230   5.106447   5.102134
# 204   3.145930   3.151076   3.146092   3.140740
# 205  12.220286  12.375236  12.325166  12.271920
#
# [206 rows x 1008 columns]

# %%
df_years = df[["country","hdi_1990","hdi_1991","hdi_1992","hdi_1993","hdi_1994","hdi_1995","hdi_1996","hdi_1997","hdi_1998","hdi_1999","hdi_2000","hdi_2001","hdi_2002","hdi_2003","hdi_2004","hdi_2005","hdi_2006",
                "hdi_2007","hdi_2008","hdi_2009","hdi_2010","hdi_2011","hdi_2012","hdi_2013","hdi_2014","hdi_2015","hdi_2016","hdi_2017","hdi_2018","hdi_2019","hdi_2020","hdi_2021"]]
df_years = df_years[:195]
df_years
# Out:
#                   country  hdi_1990  hdi_1991  hdi_1992  hdi_1993  hdi_1994  \
# 0             Afghanistan   0.27300   0.27900   0.28700   0.29700    0.2920
# 1                  Angola   0.51685   0.52020   0.52175   0.52455    0.5299
# 2                 Albania   0.64700   0.62900   0.61400   0.61700    0.6240
# 3                 Andorra   0.80920   0.81415   0.82010   0.82630    0.8348
# 4    United Arab Emirates   0.72800   0.73900   0.74200   0.74800    0.7550
# ..                    ...       ...       ...       ...       ...       ...
# 190                 Samoa   0.51070   0.51485   0.51785   0.52200    0.5281
# 191                 Yemen   0.38300   0.38600   0.39100   0.39700    0.3990
# 192          South Africa   0.63200   0.64100   0.64700   0.65200    0.6580
# 193                Zambia   0.41200   0.40800   0.40800   0.41400    0.4110
# 194              Zimbabwe   0.50900   0.51200   0.49800   0.49100    0.4860
#
#      hdi_1995  hdi_1996  hdi_1997  hdi_1998  ...  hdi_2012  hdi_2013  \
# 0     0.31000   0.31900    0.3230   0.32400  ...     0.466     0.474
# 1     0.54200   0.54795    0.5513   0.55565  ...     0.541     0.552
# 2     0.63400   0.64500    0.6420   0.65700  ...     0.778     0.785
# 3     0.83875   0.84425    0.8499   0.85690  ...     0.869     0.864
# 4     0.76200   0.76700    0.7730   0.77900  ...     0.846     0.852
# ..        ...       ...       ...       ...  ...       ...       ...
# 190   0.65900   0.66800    0.6700   0.67400  ...     0.709     0.710
# 191   0.40900   0.41900    0.4270   0.43500  ...     0.512     0.513
# 192   0.66100   0.65600    0.6510   0.64400  ...     0.696     0.704
# 193   0.41300   0.41400    0.4130   0.41100  ...     0.548     0.554
# 194   0.47700   0.47600    0.4720   0.46600  ...     0.557     0.567
#
#      hdi_2014  hdi_2015  hdi_2016  hdi_2017  hdi_2018  hdi_2019  hdi_2020  \
# 0       0.479     0.478     0.481     0.482     0.483     0.488     0.483
# 1       0.563     0.582     0.596     0.597     0.595     0.595     0.590
# 2       0.792     0.795     0.798     0.802     0.806     0.810     0.794
# 3       0.871     0.867     0.871     0.868     0.872     0.873     0.848
# 4       0.859     0.865     0.870     0.897     0.909     0.920     0.912
# ..        ...       ...       ...       ...       ...       ...       ...
# 190     0.711     0.716     0.717     0.716     0.716     0.715     0.712
# 191     0.505     0.477     0.467     0.459     0.459     0.461     0.460
# 192     0.712     0.716     0.719     0.720     0.726     0.736     0.727
# 193     0.557     0.562     0.564     0.568     0.572     0.575     0.570
# 194     0.576     0.582     0.588     0.594     0.602     0.601     0.600
#
#      hdi_2021
# 0       0.478
# 1       0.586
# 2       0.796
# 3       0.858
# 4       0.911
# ..        ...
# 190     0.707
# 191     0.455
# 192     0.713
# 193     0.565
# 194     0.593
#
# [195 rows x 33 columns]

# %%
years = [0]
for col in df_years.columns:
    time = col[-4:len(col)]
    try:
        time = int(time)
        if time not in years:
            years.append(time)
    except:
        continue
        
years
# Out:
# [0,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
df_trans = df_years.transpose()
df_trans.reset_index(inplace=True)
df_trans["index"] = years
df_trans
# Out:
#     index            0        1        2        3                     4  \
# 0       0  Afghanistan   Angola  Albania  Andorra  United Arab Emirates
# 1    1990        0.273  0.51685    0.647   0.8092                 0.728
# 2    1991        0.279   0.5202    0.629  0.81415                 0.739
# 3    1992        0.287  0.52175    0.614   0.8201                 0.742
# 4    1993        0.297  0.52455    0.617   0.8263                 0.748
# 5    1994        0.292   0.5299    0.624   0.8348                 0.755
# 6    1995         0.31    0.542    0.634  0.83875                 0.762
# 7    1996        0.319  0.54795    0.645  0.84425                 0.767
# 8    1997        0.323   0.5513    0.642   0.8499                 0.773
# 9    1998        0.324  0.55565    0.657   0.8569                 0.779
# 10   1999        0.332    0.364    0.669  0.86085                 0.787
# 11   2000        0.335    0.375    0.677    0.818                 0.796
# 12   2001        0.337    0.386    0.684    0.825                   0.8
# 13   2002        0.362    0.403    0.689    0.832                 0.804
# 14   2003        0.376     0.42    0.696    0.841                 0.814
# 15   2004        0.392    0.433      0.7    0.833                 0.818
# 16   2005          0.4    0.447    0.711    0.833                 0.822
# 17   2006        0.409    0.459    0.718    0.848                 0.827
# 18   2007        0.424    0.475     0.73    0.847                 0.831
# 19   2008         0.43    0.486    0.736     0.85                 0.834
# 20   2009         0.44      0.5    0.741    0.848                 0.833
# 21   2010        0.448     0.51    0.754    0.848                 0.835
# 22   2011        0.456    0.526    0.766    0.849                  0.84
# 23   2012        0.466    0.541    0.778    0.869                 0.846
# 24   2013        0.474    0.552    0.785    0.864                 0.852
# 25   2014        0.479    0.563    0.792    0.871                 0.859
# 26   2015        0.478    0.582    0.795    0.867                 0.865
# 27   2016        0.481    0.596    0.798    0.871                  0.87
# 28   2017        0.482    0.597    0.802    0.868                 0.897
# 29   2018        0.483    0.595    0.806    0.872                 0.909
# 30   2019        0.488    0.595     0.81    0.873                  0.92
# 31   2020        0.483     0.59    0.794    0.848                 0.912
# 32   2021        0.478    0.586    0.796    0.858                 0.911
#
#             5        6                    7          8  ...         185  \
# 0   Argentina  Armenia  Antigua and Barbuda  Australia  ...  Uzbekistan
# 1       0.723    0.656               0.6528      0.865  ...     0.48115
# 2        0.73    0.649               0.6575      0.867  ...     0.48415
# 3       0.735    0.618               0.6621      0.869  ...      0.4872
# 4       0.739    0.616              0.66555      0.873  ...     0.49105
# 5       0.744     0.62               0.6694      0.873  ...     0.49685
# 6       0.745    0.627               0.6719      0.882  ...      0.5093
# 7       0.751    0.632              0.67755      0.884  ...      0.5164
# 8       0.756    0.641               0.6831      0.887  ...     0.52255
# 9       0.762    0.654               0.6879      0.891  ...       0.527
# 10      0.773    0.657              0.69175      0.894  ...     0.53275
# 11      0.779    0.662               0.7065      0.896  ...       0.607
# 12      0.784    0.666              0.71135        0.9  ...       0.614
# 13      0.785    0.676                0.716      0.902  ...       0.621
# 14      0.793    0.686              0.72435      0.906  ...       0.627
# 15      0.798    0.694               0.7294      0.908  ...       0.634
# 16      0.802    0.707               0.7363      0.911  ...       0.639
# 17      0.814    0.721              0.74105      0.914  ...       0.644
# 18      0.817    0.738                0.802      0.915  ...       0.656
# 19      0.825    0.742                0.801      0.919  ...       0.659
# 20      0.827    0.741                0.795      0.921  ...       0.665
# 21      0.834    0.746                 0.79      0.923  ...       0.673
# 22      0.841     0.75                0.783      0.926  ...        0.68
# 23      0.843    0.755                0.787       0.93  ...       0.687
# 24      0.845     0.76                0.787      0.929  ...       0.693
# 25      0.846    0.764                0.789      0.931  ...       0.698
# 26      0.848    0.766                0.791      0.933  ...       0.701
# 27      0.847    0.765                0.794      0.935  ...       0.709
# 28      0.851    0.768                0.795      0.937  ...       0.715
# 29       0.85    0.771                0.798      0.941  ...        0.72
# 30      0.852    0.778                  0.8      0.941  ...       0.726
# 31       0.84    0.757                0.788      0.947  ...       0.721
# 32      0.842    0.759                0.788      0.951  ...       0.727
#
#                                  186                                 187  \
# 0   Saint Vincent and the Grenadines  Venezuela (Bolivarian Republic of)
# 1                            0.60865                               0.659
# 2                             0.6114                               0.669
# 3                             0.6136                               0.675
# 4                            0.61825                               0.676
# 5                              0.622                               0.675
# 6                            0.62855                               0.679
# 7                             0.6328                               0.679
# 8                             0.6369                               0.685
# 9                             0.6411                               0.686
# 10                             0.645                               0.682
# 11                             0.683                               0.684
# 12                             0.689                               0.689
# 13                             0.695                               0.699
# 14                             0.702                               0.693
# 15                             0.708                               0.707
# 16                             0.713                               0.721
# 17                             0.722                               0.732
# 18                              0.73                               0.749
# 19                             0.734                               0.756
# 20                             0.736                               0.756
# 21                             0.734                               0.755
# 22                             0.736                               0.762
# 23                             0.737                               0.767
# 24                             0.743                               0.774
# 25                             0.752                                0.77
# 26                             0.759                               0.767
# 27                             0.765                               0.757
# 28                             0.774                               0.744
# 29                             0.775                               0.738
# 30                             0.769                               0.721
# 31                             0.764                               0.695
# 32                             0.751                               0.691
#
#          188      189      190    191           192     193       194
# 0   Viet Nam  Vanuatu    Samoa  Yemen  South Africa  Zambia  Zimbabwe
# 1      0.482   0.4149   0.5107  0.383         0.632   0.412     0.509
# 2      0.493   0.4173  0.51485  0.386         0.641   0.408     0.512
# 3      0.504  0.41555  0.51785  0.391         0.647   0.408     0.498
# 4      0.515  0.41545    0.522  0.397         0.652   0.414     0.491
# 5      0.526  0.41815   0.5281  0.399         0.658   0.411     0.486
# 6      0.539   0.4217    0.659  0.409         0.661   0.413     0.477
# 7       0.55   0.4244    0.668  0.419         0.656   0.414     0.476
# 8       0.56   0.4278     0.67  0.427         0.651   0.413     0.472
# 9      0.569  0.43085    0.674  0.435         0.644   0.411     0.466
# 10     0.578   0.4402    0.678  0.441         0.638   0.413     0.457
# 11     0.588  0.46275    0.683   0.45         0.633   0.418     0.452
# 12     0.598  0.46935     0.69   0.46         0.629   0.425     0.441
# 13     0.608   0.4736    0.689  0.468         0.633   0.434     0.452
# 14     0.617   0.4801    0.694  0.476         0.629   0.448     0.439
# 15     0.625   0.4857    0.698  0.483          0.63   0.459     0.446
# 16     0.633    0.578    0.701  0.489         0.632   0.472     0.448
# 17     0.641    0.584    0.703  0.494         0.637   0.484     0.452
# 18     0.648    0.585    0.708  0.498         0.644   0.495     0.454
# 19     0.653    0.591    0.709  0.501         0.653   0.506     0.454
# 20     0.658    0.591      0.7  0.506         0.665   0.519     0.486
# 21     0.663    0.591    0.713   0.51         0.675   0.529     0.512
# 22     0.668    0.593    0.713  0.509         0.686   0.534     0.535
# 23     0.672     0.59    0.709  0.512         0.696   0.548     0.557
# 24     0.676    0.593     0.71  0.513         0.704   0.554     0.567
# 25      0.68    0.595    0.711  0.505         0.712   0.557     0.576
# 26     0.684    0.595    0.716  0.477         0.716   0.562     0.582
# 27     0.688    0.596    0.717  0.467         0.719   0.564     0.588
# 28     0.692    0.599    0.716  0.459          0.72   0.568     0.594
# 29     0.697    0.603    0.716  0.459         0.726   0.572     0.602
# 30     0.703    0.611    0.715  0.461         0.736   0.575     0.601
# 31      0.71    0.608    0.712   0.46         0.727    0.57       0.6
# 32     0.703    0.607    0.707  0.455         0.713   0.565     0.593
#
# [33 rows x 196 columns]

# %%
df_trans.rename(columns={"index":"years"}, inplace=True)
x = df_trans[df_trans.years == 0].drop("years", axis=1)
cols = []
for col in x.values:
    for i in col:
        cols.append(i)
x.columns = cols
y = df_trans.years
df_trans.drop("years", axis=1, inplace=True)
df_trans.columns = cols
df_trans["years"] = y
df_trans.drop(0, axis=0, inplace=True)
df_trans.reset_index(drop="index", inplace=True)
df_trans
# Out:
#    Afghanistan   Angola Albania  Andorra United Arab Emirates Argentina  \
# 0        0.273  0.51685   0.647   0.8092                0.728     0.723
# 1        0.279   0.5202   0.629  0.81415                0.739      0.73
# 2        0.287  0.52175   0.614   0.8201                0.742     0.735
# 3        0.297  0.52455   0.617   0.8263                0.748     0.739
# 4        0.292   0.5299   0.624   0.8348                0.755     0.744
# 5         0.31    0.542   0.634  0.83875                0.762     0.745
# 6        0.319  0.54795   0.645  0.84425                0.767     0.751
# 7        0.323   0.5513   0.642   0.8499                0.773     0.756
# 8        0.324  0.55565   0.657   0.8569                0.779     0.762
# 9        0.332    0.364   0.669  0.86085                0.787     0.773
# 10       0.335    0.375   0.677    0.818                0.796     0.779
# 11       0.337    0.386   0.684    0.825                  0.8     0.784
# 12       0.362    0.403   0.689    0.832                0.804     0.785
# 13       0.376     0.42   0.696    0.841                0.814     0.793
# 14       0.392    0.433     0.7    0.833                0.818     0.798
# 15         0.4    0.447   0.711    0.833                0.822     0.802
# 16       0.409    0.459   0.718    0.848                0.827     0.814
# 17       0.424    0.475    0.73    0.847                0.831     0.817
# 18        0.43    0.486   0.736     0.85                0.834     0.825
# 19        0.44      0.5   0.741    0.848                0.833     0.827
# 20       0.448     0.51   0.754    0.848                0.835     0.834
# 21       0.456    0.526   0.766    0.849                 0.84     0.841
# 22       0.466    0.541   0.778    0.869                0.846     0.843
# 23       0.474    0.552   0.785    0.864                0.852     0.845
# 24       0.479    0.563   0.792    0.871                0.859     0.846
# 25       0.478    0.582   0.795    0.867                0.865     0.848
# 26       0.481    0.596   0.798    0.871                 0.87     0.847
# 27       0.482    0.597   0.802    0.868                0.897     0.851
# 28       0.483    0.595   0.806    0.872                0.909      0.85
# 29       0.488    0.595    0.81    0.873                 0.92     0.852
# 30       0.483     0.59   0.794    0.848                0.912      0.84
# 31       0.478    0.586   0.796    0.858                0.911     0.842
#
#    Armenia Antigua and Barbuda Australia Austria  ...  \
# 0    0.656              0.6528     0.865   0.825  ...
# 1    0.649              0.6575     0.867   0.829  ...
# 2    0.618              0.6621     0.869   0.835  ...
# 3    0.616             0.66555     0.873    0.84  ...
# 4     0.62              0.6694     0.873   0.845  ...
# 5    0.627              0.6719     0.882   0.849  ...
# 6    0.632             0.67755     0.884   0.853  ...
# 7    0.641              0.6831     0.887   0.857  ...
# 8    0.654              0.6879     0.891   0.863  ...
# 9    0.657             0.69175     0.894   0.866  ...
# 10   0.662              0.7065     0.896   0.871  ...
# 11   0.666             0.71135       0.9   0.876  ...
# 12   0.676               0.716     0.902   0.879  ...
# 13   0.686             0.72435     0.906   0.881  ...
# 14   0.694              0.7294     0.908   0.886  ...
# 15   0.707              0.7363     0.911   0.889  ...
# 16   0.721             0.74105     0.914   0.893  ...
# 17   0.738               0.802     0.915   0.896  ...
# 18   0.742               0.801     0.919   0.898  ...
# 19   0.741               0.795     0.921   0.898  ...
# 20   0.746                0.79     0.923   0.902  ...
# 21    0.75               0.783     0.926   0.905  ...
# 22   0.755               0.787      0.93   0.906  ...
# 23    0.76               0.787     0.929   0.905  ...
# 24   0.764               0.789     0.931   0.909  ...
# 25   0.766               0.791     0.933    0.91  ...
# 26   0.765               0.794     0.935   0.915  ...
# 27   0.768               0.795     0.937   0.916  ...
# 28   0.771               0.798     0.941   0.917  ...
# 29   0.778                 0.8     0.941   0.919  ...
# 30   0.757               0.788     0.947   0.913  ...
# 31   0.759               0.788     0.951   0.916  ...
#
#    Saint Vincent and the Grenadines Venezuela (Bolivarian Republic of)  \
# 0                           0.60865                              0.659
# 1                            0.6114                              0.669
# 2                            0.6136                              0.675
# 3                           0.61825                              0.676
# 4                             0.622                              0.675
# 5                           0.62855                              0.679
# 6                            0.6328                              0.679
# 7                            0.6369                              0.685
# 8                            0.6411                              0.686
# 9                             0.645                              0.682
# 10                            0.683                              0.684
# 11                            0.689                              0.689
# 12                            0.695                              0.699
# 13                            0.702                              0.693
# 14                            0.708                              0.707
# 15                            0.713                              0.721
# 16                            0.722                              0.732
# 17                             0.73                              0.749
# 18                            0.734                              0.756
# 19                            0.736                              0.756
# 20                            0.734                              0.755
# 21                            0.736                              0.762
# 22                            0.737                              0.767
# 23                            0.743                              0.774
# 24                            0.752                               0.77
# 25                            0.759                              0.767
# 26                            0.765                              0.757
# 27                            0.774                              0.744
# 28                            0.775                              0.738
# 29                            0.769                              0.721
# 30                            0.764                              0.695
# 31                            0.751                              0.691
#
#    Viet Nam  Vanuatu    Samoa  Yemen South Africa Zambia Zimbabwe years
# 0     0.482   0.4149   0.5107  0.383        0.632  0.412    0.509  1990
# 1     0.493   0.4173  0.51485  0.386        0.641  0.408    0.512  1991
# 2     0.504  0.41555  0.51785  0.391        0.647  0.408    0.498  1992
# 3     0.515  0.41545    0.522  0.397        0.652  0.414    0.491  1993
# 4     0.526  0.41815   0.5281  0.399        0.658  0.411    0.486  1994
# 5     0.539   0.4217    0.659  0.409        0.661  0.413    0.477  1995
# 6      0.55   0.4244    0.668  0.419        0.656  0.414    0.476  1996
# 7      0.56   0.4278     0.67  0.427        0.651  0.413    0.472  1997
# 8     0.569  0.43085    0.674  0.435        0.644  0.411    0.466  1998
# 9     0.578   0.4402    0.678  0.441        0.638  0.413    0.457  1999
# 10    0.588  0.46275    0.683   0.45        0.633  0.418    0.452  2000
# 11    0.598  0.46935     0.69   0.46        0.629  0.425    0.441  2001
# 12    0.608   0.4736    0.689  0.468        0.633  0.434    0.452  2002
# 13    0.617   0.4801    0.694  0.476        0.629  0.448    0.439  2003
# 14    0.625   0.4857    0.698  0.483         0.63  0.459    0.446  2004
# 15    0.633    0.578    0.701  0.489        0.632  0.472    0.448  2005
# 16    0.641    0.584    0.703  0.494        0.637  0.484    0.452  2006
# 17    0.648    0.585    0.708  0.498        0.644  0.495    0.454  2007
# 18    0.653    0.591    0.709  0.501        0.653  0.506    0.454  2008
# 19    0.658    0.591      0.7  0.506        0.665  0.519    0.486  2009
# 20    0.663    0.591    0.713   0.51        0.675  0.529    0.512  2010
# 21    0.668    0.593    0.713  0.509        0.686  0.534    0.535  2011
# 22    0.672     0.59    0.709  0.512        0.696  0.548    0.557  2012
# 23    0.676    0.593     0.71  0.513        0.704  0.554    0.567  2013
# 24     0.68    0.595    0.711  0.505        0.712  0.557    0.576  2014
# 25    0.684    0.595    0.716  0.477        0.716  0.562    0.582  2015
# 26    0.688    0.596    0.717  0.467        0.719  0.564    0.588  2016
# 27    0.692    0.599    0.716  0.459         0.72  0.568    0.594  2017
# 28    0.697    0.603    0.716  0.459        0.726  0.572    0.602  2018
# 29    0.703    0.611    0.715  0.461        0.736  0.575    0.601  2019
# 30     0.71    0.608    0.712   0.46        0.727   0.57      0.6  2020
# 31    0.703    0.607    0.707  0.455        0.713  0.565    0.593  2021
#
# [32 rows x 196 columns]

# %%
df_afg = df_trans[["years", "Afghanistan"]]
df_afg["country"] = "Afghanistan"
df_afg.rename(columns={"Afghanistan":"hdi"}, inplace=True)
# Out:
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\490331345.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_afg["country"] = "Afghanistan"
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\490331345.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_afg.rename(columns={"Afghanistan":"hdi"}, inplace=True)

# %%
df_ang = df_trans[["years", "Angola"]]
df_ang["country"] = "Angola"
df_ang.rename(columns={"Angola":"hdi"}, inplace=True)
df_afg_ang = pd.concat([df_afg, df_ang])
df_afg_ang.reset_index(drop="index", inplace=True)
df_afg_ang
# Out:
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\799887493.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ang["country"] = "Angola"
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\799887493.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ang.rename(columns={"Angola":"hdi"}, inplace=True)
#     years    hdi      country
# 0    1990  0.273  Afghanistan
# 1    1991  0.279  Afghanistan
# 2    1992  0.287  Afghanistan
# 3    1993  0.297  Afghanistan
# 4    1994  0.292  Afghanistan
# ..    ...    ...          ...
# 59   2017  0.597       Angola
# 60   2018  0.595       Angola
# 61   2019  0.595       Angola
# 62   2020   0.59       Angola
# 63   2021  0.586       Angola
#
# [64 rows x 3 columns]

# %%
def df_years_maker(df, df_with_iso=None):
    df_new = pd.DataFrame()
    df_tmp = pd.DataFrame()
    df_yearless = df.drop("years", axis=1)
    for col in df_yearless.columns:
        df_tmp = df_yearless[[col]]
        df_tmp["years"] = df["years"]
        df_tmp["country"] = col
        iso = df_with_iso.loc[df_with_iso["country"]==col, "iso3"]
        iso_string = str(iso.values[0])
        df_tmp["iso"] = iso_string
        df_tmp.rename(columns={col:"hdi"}, inplace=True)
        df_new = pd.concat([df_new, df_tmp])
        df_new.reset_index(drop="index", inplace=True)
        df_new
    
    return df_new

# %%
df_years = df_years_maker(df_trans, df)
df_years
# Out:
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["years"] = df["years"]
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["country"] = col
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["iso"] = iso_string
# C:\Users\pigop\AppData\Local\Temp\ipykernel_7968\3913421325.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp.rename(columns={col:"hdi"}, inplace=True)
#         hdi  years      country  iso
# 0     0.273   1990  Afghanistan  AFG
# 1     0.279   1991  Afghanistan  AFG
# 2     0.287   1992  Afghanistan  AFG
# 3     0.297   1993  Afghanistan  AFG
# 4     0.292   1994  Afghanistan  AFG
# ...     ...    ...          ...  ...
# 6235  0.594   2017     Zimbabwe  ZWE
# 6236  0.602   2018     Zimbabwe  ZWE
# 6237  0.601   2019     Zimbabwe  ZWE
# 6238    0.6   2020     Zimbabwe  ZWE
# 6239  0.593   2021     Zimbabwe  ZWE
#
# [6240 rows x 4 columns]

# %%
fig = px.scatter_geo(df_years, locations="iso", color="country",
                     hover_name="country", size="hdi",
                     animation_frame="years",
                     projection="natural earth")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:768, in NumberValidator.validate_coerce(self, v)
#     767 try:
# --> 768     v_array = copy_to_readonly_numpy_array(v, force_numeric=True)
#     769 except (ValueError, TypeError, OverflowError):
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:121, in copy_to_readonly_numpy_array(v, kind, force_numeric)
#     120 if is_numpy_convertable(v):
# --> 121     return copy_to_readonly_numpy_array(
#     122         np.array(v), kind=kind, force_numeric=force_numeric
#     123     )
#     124 else:
#     125     # v is not homogenous array
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:150, in copy_to_readonly_numpy_array(v, kind, force_numeric)
#     149 if force_numeric and new_v.dtype.kind not in numeric_kinds:
# --> 150     raise ValueError(
#     151         "Input value is not numeric and" "force_numeric parameter set to True"
#     152     )
#     154 if "U" not in kind:
#     155     # Force non-numeric arrays to have object type
#     156     # --------------------------------------------
#    (...)
#     159     # numpy converts the integers to strings and returns array of dtype
#     160     # '<U21'
#
# ValueError: Input value is not numeric andforce_numeric parameter set to True
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\datavisualization_project_passonipuiattivairani\project_puiatti.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/datavisualization_project_passonipuiattivairani/project_puiatti.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> fig = px.scatter_geo(df_years, locations="iso", color="country",
#       <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/datavisualization_project_passonipuiattivairani/project_puiatti.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a>                      hover_name="country", size="hdi",
#       <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/datavisualization_project_passonipuiattivairani/project_puiatti.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>                      animation_frame="years",
#       <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/datavisualization_project_passonipuiattivairani/project_puiatti.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a>                      projection="natural earth")
#       <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/datavisualization_project_passonipuiattivairani/project_puiatti.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> fig.show()
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_chart_types.py:1145, in scatter_geo(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, text, symbol, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1098 def scatter_geo(
#    1099     data_frame=None,
#    1100     lat=None,
#    (...)
#    1139     height=None,
#    1140 ):
#    1141     """
#    1142     In a geographic scatter plot, each row of `data_frame` is represented
#    1143     by a symbol mark on a map.
#    1144     """
# -> 1145     return make_figure(
#    1146         args=locals(),
#    1147         constructor=go.Scattergeo,
#    1148         trace_patch=dict(locationmode=locationmode),
#    1149     )
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\express\_core.py:2129, in make_figure(args, constructor, trace_patch, layout_patch)
#    2124         group[var] = 100.0 * group[var] / group_sum
#    2126 patch, fit_results = make_trace_kwargs(
#    2127     args, trace_spec, group, mapping_labels.copy(), sizeref
#    2128 )
# -> 2129 trace.update(patch)
#    2130 if fit_results is not None:
#    2131     trendline_rows.append(mapping_labels.copy())
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5101, in BasePlotlyType.update(self, dict1, overwrite, **kwargs)
#    5099         BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5100 else:
# -> 5101     BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#    5102     BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5104 return self
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:3910, in BaseFigure._perform_update(plotly_obj, update_obj, overwrite)
#    3904 validator = plotly_obj._get_prop_validator(key)
#    3906 if isinstance(validator, CompoundValidator) and isinstance(val, dict):
#    3907
#    3908     # Update compound objects recursively
#    3909     # plotly_obj[key].update(val)
# -> 3910     BaseFigure._perform_update(plotly_obj[key], val)
#    3911 elif isinstance(validator, CompoundArrayValidator):
#    3912     if plotly_obj[key]:
#    3913         # plotly_obj has an existing non-empty array for key
#    3914         # In this case we merge val into the existing elements
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:3931, in BaseFigure._perform_update(plotly_obj, update_obj, overwrite)
#    3928                 plotly_obj[key] = val
#    3929         else:
#    3930             # Assign non-compound value
# -> 3931             plotly_obj[key] = val
#    3933 elif isinstance(plotly_obj, tuple):
#    3935     if len(update_obj) == 0:
#    3936         # Nothing to do
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:4836, in BasePlotlyType.__setitem__(self, prop, value)
#    4832         self._set_array_prop(prop, value)
#    4834     # ### Handle simple property ###
#    4835     else:
# -> 4836         self._set_prop(prop, value)
#    4837 else:
#    4838     # Make sure properties dict is initialized
#    4839     self._init_props()
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5180, in BasePlotlyType._set_prop(self, prop, val)
#    5178         return
#    5179     else:
# -> 5180         raise err
#    5182 # val is None
#    5183 # -----------
#    5184 if val is None:
#    5185     # Check if we should send null update
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5175, in BasePlotlyType._set_prop(self, prop, val)
#    5172 validator = self._get_validator(prop)
#    5174 try:
# -> 5175     val = validator.validate_coerce(val)
#    5176 except ValueError as err:
#    5177     if self._skip_invalid:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:770, in NumberValidator.validate_coerce(self, v)
#     768     v_array = copy_to_readonly_numpy_array(v, force_numeric=True)
#     769 except (ValueError, TypeError, OverflowError):
# --> 770     self.raise_invalid_val(v)
#     772 # Check min/max
#     773 if self.has_min_max:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:289, in BaseValidator.raise_invalid_val(self, v, inds)
#     286             for i in inds:
#     287                 name += "[" + str(i) + "]"
# --> 289         raise ValueError(
#     290             """
#     291     Invalid value of type {typ} received for the '{name}' property of {pname}
#     292         Received value: {v}
#     293
#     294 {valid_clr_desc}""".format(
#     295                 name=name,
#     296                 pname=self.parent_name,
#     297                 typ=type_str(v),
#     298                 v=repr(v),
#     299                 valid_clr_desc=self.description(),
#     300             )
#     301         )
#
# ValueError:
#     Invalid value of type 'pandas.core.series.Series' received for the 'size' property of scattergeo.marker
#         Received value: 0    0.273
# Name: hdi, dtype: object
#
#     The 'size' property is a number and may be specified as:
#       - An int or float in the interval [0, inf]
#       - A tuple, list, or one-dimensional numpy array of the above

# %%
df1 = df.iloc[:103]
df2 = df.iloc[104:]
print(len(df1), len(df2))
# Out:
# 103 102

# %%
# declare an empty list to store
# latitude and longitude of values 
# of city column

# function to find the coordinate
# of a given city 
def findGeocode(city):
       
    # try and catch is used to overcome
    # the exception thrown by geolocator
    # using geocodertimedout  
    try:
          
        # Specify the user_agent as your
        # app name it should not be none
        geolocator = Nominatim(user_agent="your_app_name")
          
        return geolocator.geocode(city)
      
    except GeocoderTimedOut:
          
        return findGeocode(city)    
  
# each value from city column
# will be fetched and sent to
# function find_geocode

# %%
latitude = []
longitude = []

for i in (df1["country"]):
    print(i)
    if findGeocode(i) != None:
           
        loc = findGeocode(i)
          
        # coordinates returned from 
        # function is stored into
        # two separate list
        latitude.append(loc.latitude)
        longitude.append(loc.longitude)
       
    # if coordinate for a city not
    # found, insert "NaN" indicating 
    # missing value 
    else:
        latitude.append(np.nan)
        longitude.append(np.nan)

df1["longitude"] = longitude
df1["latitude"] = latitude
# Out:
# Afghanistan
# Angola
# Albania
# Andorra
# United Arab Emirates
# Argentina
# Armenia
# Antigua and Barbuda
# Australia
# Austria
# Azerbaijan
# Burundi
# Belgium
# Benin
# Burkina Faso
# Bangladesh
# Bulgaria
# Bahrain
# Bahamas
# Bosnia and Herzegovina
# Belarus
# Belize
# Bolivia (Plurinational State of)
# Brazil
# Barbados
# Brunei Darussalam
# Bhutan
# Botswana
# Central African Republic
# Canada
# Switzerland
# Chile
# China
# Côte d'Ivoire
# Cameroon
# Congo (Democratic Republic of the)
# Congo
# Colombia
# Comoros
# Cabo Verde
# Costa Rica
# Cuba
# Cyprus
# Czechia
# Germany
# Djibouti
# Dominica
# Denmark
# Dominican Republic
# Algeria
# Ecuador
# Egypt
# Eritrea
# Spain
# Estonia
# Ethiopia
# Finland
# Fiji
# France
# Micronesia (Federated States of)
# Gabon
# United Kingdom
# Georgia
# Ghana
# Guinea
# Gambia
# Guinea-Bissau
# Equatorial Guinea
# Greece
# Grenada
# Guatemala
# Guyana
# Hong Kong, China (SAR)
# Honduras
# Croatia
# Haiti
# Hungary
# Indonesia
# India
# Ireland
# Iran (Islamic Republic of)
# Iraq
# Iceland
# Israel
# Italy
# Jamaica
# Jordan
# Japan
# Kazakhstan
# Kenya
# Kyrgyzstan
# Cambodia
# Kiribati
# Saint Kitts and Nevis
# Korea (Republic of)
# Kuwait
# Lao People's Democratic Republic
# Lebanon
# Liberia
# Libya
# Saint Lucia
# Liechtenstein
# Sri Lanka
# C:\Users\pigop\AppData\Local\Temp\ipykernel_15004\3014805000.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["longitude"] = longitude
# C:\Users\pigop\AppData\Local\Temp\ipykernel_15004\3014805000.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["latitude"] = latitude

# %%
latitude = []
longitude = []

for i in (df2["country"]):
    print(i)
    if findGeocode(i) != None:
        loc = findGeocode(i)
        
        # coordinates returned from 
        # function is stored into
        # two separate list
        latitude.append(loc.latitude)
        longitude.append(loc.longitude)
       
    # if coordinate for a city not
    # found, insert "NaN" indicating 
    # missing value 
    else:
        latitude.append(np.nan)
        longitude.append(np.nan)

df2["longitude"] = longitude
df2["latitude"] = latitude
# Out:
# Lithuania
# Luxembourg
# Latvia
# Morocco
# Monaco
# Moldova (Republic of)
# Madagascar
# Maldives
# Mexico
# Marshall Islands
# North Macedonia
# Mali
# Malta
# Myanmar
# Montenegro
# Mongolia
# Mozambique
# Mauritania
# Mauritius
# Malawi
# Malaysia
# Namibia
# Niger
# Nigeria
# Nicaragua
# Netherlands
# Norway
# Nepal
# Nauru
# New Zealand
# Oman
# Pakistan
# Panama
# Peru
# Philippines
# Palau
# Papua New Guinea
# Poland
# Korea (Democratic People's Rep. of)
# Portugal
# Paraguay
# Palestine, State of
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# ...
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# GeocoderTimedOut                          Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:319, in URLLibAdapter.get_text(self, url, timeout, headers)
#     318 elif isinstance(error, SocketTimeout):
# --> 319     raise GeocoderTimedOut("Service timed out")
#     320 elif isinstance(error, SSLError):
#
# GeocoderTimedOut: Service timed out
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1128 if buffer is not None:
# -> 1129     return self._sslobj.read(len, buffer)
#    1130 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> for i in (df2["country"]):
#       <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     print(i)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     if findGeocode(i) != None:
#       <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>         loc = findGeocode(i)
#       <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>         # coordinates returned from
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>         # function is stored into
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>         # two separate list
#
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a>     return findGeocode(city)
#
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a>     return findGeocode(city)
#
#     [... skipping similar frames: findGeocode at line 22 (29 times)]
#
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a>     return findGeocode(city)
#
# c:\Users\pigop\OneDrive\Documents\Supsi\DSIA 2\Visualization\visualize_project\project.ipynb Cell 10 in findGeocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a> try:
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a>     # Specify the user_agent as your
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a>     # app name it should not be none
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     geolocator = Nominatim(user_agent="your_app_name")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     return geolocator.geocode(city)
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> except GeocoderTimedOut:
#      <a href='vscode-notebook-cell:/c%3A/Users/pigop/OneDrive/Documents/Supsi/DSIA%202/Visualization/visualize_project/project.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a>     return findGeocode(city)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297 return self._call_geocoder(url, callback, timeout=timeout)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:286, in URLLibAdapter.get_json(self, url, timeout, headers)
#     285 def get_json(self, url, *, timeout, headers):
# --> 286     text = self.get_text(url, timeout=timeout, headers=headers)
#     287     try:
#     288         return json.loads(text)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\site-packages\geopy\adapters.py:297, in URLLibAdapter.get_text(self, url, timeout, headers)
#     295 req = Request(url=url, headers=headers)
#     296 try:
# --> 297     page = self.urlopen(req, timeout=timeout)
#     298 except Exception as error:
#     299     message = str(error.args[0]) if len(error.args) else str(error)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\pigop\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df1.dtypes
# Out:
# iso3              object
# country           object
# hdicode           object
# region            object
# hdi_rank_2021    float64
#                   ...
# mf_2019          float64
# mf_2020          float64
# mf_2021          float64
# longitude        float64
# latitude         float64
# Length: 1010, dtype: object

# %%
df_long_lat = pd.concat([df1,df2])
df_long_lat.fillna(0)
# Out:
#           iso3                          country    hdicode region  \
# 0          AFG                      Afghanistan        Low     SA
# 1          AGO                           Angola     Medium    SSA
# 2          ALB                          Albania       High    ECA
# 3          AND                          Andorra  Very High      0
# 4          ARE             United Arab Emirates  Very High     AS
# ..         ...                              ...        ...    ...
# 201    ZZG.ECA          Europe and Central Asia          0      0
# 202    ZZH.LAC  Latin America and the Caribbean          0      0
# 203     ZZI.SA                       South Asia          0      0
# 204    ZZJ.SSA               Sub-Saharan Africa          0      0
# 205  ZZK.WORLD                            World          0      0
#
#      hdi_rank_2021  hdi_1990  hdi_1991  hdi_1992  hdi_1993  hdi_1994  ...  \
# 0           180.00   0.27300   0.27900   0.28700   0.29700    0.2920  ...
# 1           148.00   0.51685   0.52020   0.52175   0.52455    0.5299  ...
# 2            67.00   0.64700   0.62900   0.61400   0.61700    0.6240  ...
# 3            40.00   0.80920   0.81415   0.82010   0.82630    0.8348  ...
# 4            26.00   0.72800   0.73900   0.74200   0.74800    0.7550  ...
# ..             ...       ...       ...       ...       ...       ...  ...
# 201          80.95   0.66400   0.66100   0.65400   0.65200    0.6470  ...
# 202          84.90   0.63300   0.63800   0.64300   0.64800    0.6540  ...
# 203         135.75   0.44200   0.44700   0.45300   0.45700    0.4620  ...
# 204         149.95   0.40700   0.41000   0.41000   0.41100    0.4130  ...
# 205          82.15   0.60100   0.60400   0.60700   0.61000    0.6140  ...
#
#        mf_2014    mf_2015    mf_2016    mf_2017    mf_2018    mf_2019  \
# 0     1.660000   1.620000   1.660000   1.410000   1.320000   1.380000
# 1     3.970000   3.590000   2.790000   2.640000   2.280000   2.180000
# 2    13.140000  12.610000  14.390000  14.460000  12.850000  12.960000
# 3    29.524000  29.033000  29.550500  30.422000  28.991500  28.891500
# 4    55.490000  59.760000  64.950000  75.610000  65.970000  68.950000
# ..         ...        ...        ...        ...        ...        ...
# 201  14.189127  14.523162  13.791770  13.618078  13.914030  14.087293
# 202  14.080904  14.146026  13.325144  13.604555  13.151315  13.296195
# 203   4.486500   4.610546   4.624886   4.740263   5.000024   5.110230
# 204   3.491150   3.494860   3.415511   3.256156   3.145930   3.151076
# 205  12.520563  12.372667  12.277707  12.277878  12.220286  12.375236
#
#        mf_2020    mf_2021   longitude   latitude
# 0     1.380000   1.380000   66.238514  33.768006
# 1     2.180000   2.180000   17.569124 -11.877577
# 2    12.960000  12.960000   19.999962  41.000028
# 3    28.891500  28.891500    1.573203  42.540717
# 4    68.950000  68.950000   53.999483  24.000249
# ..         ...        ...         ...        ...
# 201  14.091826  14.096719    6.134686  46.228628
# 202  13.290914  13.284745  -61.513128  10.661669
# 203   5.106447   5.102134 -122.324147  47.596868
# 204   3.146092   3.140740    0.000000   0.000000
# 205  12.325166  12.271920 -121.827516  37.350899
#
# [205 rows x 1010 columns]

# %%
px.set_mapbox_access_token('pk.eyJ1IjoiZ3Bhc3NhbnRpbm8yMiIsImEiOiJjbGIybTV1OWwwNXEyM3BvYTc0MXdqYm5sIn0.F0W3QHOO9o5dJysHnj0fpA')
fig = px.scatter_mapbox(df1, lat="latitude", lon="longitude", color="hdi_rank_2021", size="hdi_1992",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=1, height=800, width= 1200, hover_name="country")
fig.show()
